# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/AI-Class-202335225-nayeonsu/blob/main/Week5/breast_cancer_Regression_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#worst compactness 이걸 label로 회귀
import numpy as np

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv')
df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 32 columns]

# %%
#Regression

from tensorflow.keras import layers, models
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score # Import regression metrics

# Assuming 'Alcohol' is the target variable (y) and the rest are features (X)
X = df.drop('worst compactness', axis=1)
y = df['worst compactness'].values # y is now a 1D numpy array of continuous values

scaler = StandardScaler()
X = scaler.fit_transform(X)

# Correct for regression: Do not one-hot encode y.
# For the output layer `layers.Dense(1)`, it expects a single value per sample.
# Reshape y to (n_samples, 1) for consistency with Keras input/output shape expectations.
Y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)


model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(1)   # Output layer for regression has 1 neuron, no activation for linear output
])

model.compile(
    optimizer="adam",
    loss="mse",   # Mean Squared Error for regression
    metrics=["mse"] # Using mse as a metric for regression
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)

y_pred = model.predict(X_test)

# For regression, y_test_class and y_pred_class using np.argmax are inappropriate.
# We are predicting continuous values, not classes. These lines are removed.

# 학습 곡선
loss = history.history['loss']
val_loss = history.history['val_loss']
# For regression, use 'mse' instead of 'accuracy'
mse = history.history['mse']
val_mse = history.history['val_mse']


# y_pred is already calculated above.

# Again, remove classification-specific conversions for regression
# y_test_class = np.argmax(y_test,axis=1)
# y_pred_class = np.argmax(y_pred,axis=1)

import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)') # Update label
plt.legend()
plt.show()

# Plot MSE instead of Accuracy
plt.plot(epochs, mse, 'y', label='Training MSE')
plt.plot(epochs, val_mse, 'r', label='Validation MSE')
plt.title('Training and validation MSE') # Update title
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# Accuracy metrics (classification_report, confusion_matrix) are not applicable to regression.
# Replace with appropriate regression evaluation metrics.
# Calculate MSE and R-squared on the test set
test_mse = mean_squared_error(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print(f"Test MSE: {test_mse:.4f}")
print(f"Test R-squared: {test_r2:.4f}")

# Removed classification metrics
# from sklearn.metrics import classification_report,confusion_matrix
# print(classification_report(y_test_class,y_pred_class))
# print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1492 - mse: 0.1492 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0560 - mse: 0.0560 - val_loss: 0.0329 - val_mse: 0.0329
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0224 - val_mse: 0.0224
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0343 - mse: 0.0343 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0044 - val_mse: 0.0044
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Test MSE: 0.0034
# Test R-squared: 0.8862

# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/AI-Class-202335225-nayeonsu/blob/main/Week6/abalone_Classification_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/abalone.csv')
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'])

# 나중에 클래스 이름을 확인하고 싶을 때
# print(encoder.classes_)
df.head()
# Out:
#    id  Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0   0    2   0.455     0.365   0.095        0.5140          0.2245
# 1   1    2   0.350     0.265   0.090        0.2255          0.0995
# 2   2    0   0.530     0.420   0.135        0.6770          0.2565
# 3   3    2   0.440     0.365   0.125        0.5160          0.2155
# 4   4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
from tensorflow.keras import layers, models
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

X = df.drop('Sex', axis=1)
y = df['Sex']

scaler = StandardScaler()
X = scaler.fit_transform(X)

Y = pd.get_dummies(y).values

from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)


model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",   # one-hot이면 categorical_crossentropy
    metrics=["accuracy"]
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)

y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)

# 학습 곡선
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy'] # Corrected from 'val_acc'
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4974 - loss: 0.9236 - val_accuracy: 0.5411 - val_loss: 0.8585
# Epoch 2/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5299 - loss: 0.8770 - val_accuracy: 0.5620 - val_loss: 0.8506
# Epoch 3/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5374 - loss: 0.8693 - val_accuracy: 0.5336 - val_loss: 0.8390
# Epoch 4/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5483 - loss: 0.8574 - val_accuracy: 0.5396 - val_loss: 0.8334
# Epoch 5/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5408 - loss: 0.8520 - val_accuracy: 0.5441 - val_loss: 0.8374
# Epoch 6/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5382 - loss: 0.8533 - val_accuracy: 0.5575 - val_loss: 0.8249
# Epoch 7/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5535 - loss: 0.8474 - val_accuracy: 0.5635 - val_loss: 0.8278
# Epoch 8/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5704 - loss: 0.8416 - val_accuracy: 0.5710 - val_loss: 0.8222
# Epoch 9/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5561 - loss: 0.8444 - val_accuracy: 0.5650 - val_loss: 0.8219
# Epoch 10/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5591 - loss: 0.8407 - val_accuracy: 0.5680 - val_loss: 0.8203
# Epoch 11/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5659 - loss: 0.8404 - val_accuracy: 0.5665 - val_loss: 0.8174
# Epoch 12/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5711 - loss: 0.8332 - val_accuracy: 0.5366 - val_loss: 0.8253
# Epoch 13/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5801 - loss: 0.8294 - val_accuracy: 0.5605 - val_loss: 0.8154
# Epoch 14/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5692 - loss: 0.8317 - val_accuracy: 0.5501 - val_loss: 0.8194
# Epoch 15/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5644 - loss: 0.8321 - val_accuracy: 0.5695 - val_loss: 0.8185
# Epoch 16/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5734 - loss: 0.8249 - val_accuracy: 0.5650 - val_loss: 0.8109
# Epoch 17/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5775 - loss: 0.8258 - val_accuracy: 0.5650 - val_loss: 0.8092
# Epoch 18/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5734 - loss: 0.8323 - val_accuracy: 0.5441 - val_loss: 0.8166
# Epoch 19/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5741 - loss: 0.8292 - val_accuracy: 0.5695 - val_loss: 0.8155
# Epoch 20/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5704 - loss: 0.8256 - val_accuracy: 0.5650 - val_loss: 0.8148
# Epoch 21/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5763 - loss: 0.8260 - val_accuracy: 0.5650 - val_loss: 0.8051
# Epoch 22/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5737 - loss: 0.8252 - val_accuracy: 0.5680 - val_loss: 0.8110
# Epoch 23/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5812 - loss: 0.8280 - val_accuracy: 0.5710 - val_loss: 0.8077
# Epoch 24/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5756 - loss: 0.8224 - val_accuracy: 0.5755 - val_loss: 0.8088
# Epoch 25/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5842 - loss: 0.8210 - val_accuracy: 0.5845 - val_loss: 0.8094
# Epoch 26/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5861 - loss: 0.8196 - val_accuracy: 0.5755 - val_loss: 0.8154
# Epoch 27/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5936 - loss: 0.8200 - val_accuracy: 0.5800 - val_loss: 0.8077
# Epoch 28/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5820 - loss: 0.8202 - val_accuracy: 0.5845 - val_loss: 0.8077
# Epoch 29/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5700 - loss: 0.8224 - val_accuracy: 0.5740 - val_loss: 0.8082
# Epoch 30/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5857 - loss: 0.8116 - val_accuracy: 0.5605 - val_loss: 0.8132
# Epoch 31/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5827 - loss: 0.8148 - val_accuracy: 0.5620 - val_loss: 0.8099
# Epoch 32/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5767 - loss: 0.8214 - val_accuracy: 0.5889 - val_loss: 0.8050
# Epoch 33/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5969 - loss: 0.8164 - val_accuracy: 0.5710 - val_loss: 0.8148
# Epoch 34/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5827 - loss: 0.8163 - val_accuracy: 0.5755 - val_loss: 0.8060
# Epoch 35/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5947 - loss: 0.8133 - val_accuracy: 0.5710 - val_loss: 0.8104
# Epoch 36/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5954 - loss: 0.8060 - val_accuracy: 0.5695 - val_loss: 0.8102
# Epoch 37/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5981 - loss: 0.8130 - val_accuracy: 0.5815 - val_loss: 0.8088
# Epoch 38/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5879 - loss: 0.8121 - val_accuracy: 0.5740 - val_loss: 0.8093
# Epoch 39/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5894 - loss: 0.8118 - val_accuracy: 0.5830 - val_loss: 0.8078
# Epoch 40/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5992 - loss: 0.8068 - val_accuracy: 0.5770 - val_loss: 0.8130
# Epoch 41/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5823 - loss: 0.8115 - val_accuracy: 0.5695 - val_loss: 0.8087
# Epoch 42/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5879 - loss: 0.8051 - val_accuracy: 0.5874 - val_loss: 0.8054
# Epoch 43/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5816 - loss: 0.8039 - val_accuracy: 0.5710 - val_loss: 0.8081
# Epoch 44/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5924 - loss: 0.8070 - val_accuracy: 0.5815 - val_loss: 0.8102
# Epoch 45/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6003 - loss: 0.8090 - val_accuracy: 0.5770 - val_loss: 0.8110
# Epoch 46/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5932 - loss: 0.8089 - val_accuracy: 0.5859 - val_loss: 0.8070
# Epoch 47/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5827 - loss: 0.8102 - val_accuracy: 0.5845 - val_loss: 0.8083
# Epoch 48/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5973 - loss: 0.8036 - val_accuracy: 0.5830 - val_loss: 0.8136
# Epoch 49/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6010 - loss: 0.8048 - val_accuracy: 0.5800 - val_loss: 0.8089
# Epoch 50/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6037 - loss: 0.8045 - val_accuracy: 0.5994 - val_loss: 0.8072
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.45      0.38      0.41       249
#            1       0.71      0.82      0.76       291
#            2       0.49      0.48      0.49       296
#
#     accuracy                           0.57       836
#    macro avg       0.55      0.56      0.55       836
# weighted avg       0.56      0.57      0.56       836
#
# [[ 95  38 116]
#  [ 22 239  30]
#  [ 95  59 142]]
